# %% [markdown]
# <a href="https://www.kaggle.com/code/moazeldsokyx/gans-text-to-image-demo?scriptVersionId=156330328" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## **Importing Required Libraries**

# %%
# !pip install diffusers --upgrade
# !pip install invisible_watermark transformers accelerate safetensors

# %%
import torch
from diffusers import DiffusionPipeline

# %% [markdown]
# # Creating a DiffusionPipeline with specified parameters
#
# - Model: stabilityai/stable-diffusion-xl-base-1.0
# - Torch data type: torch.float16
# - Using SafeTensors for enhanced safety
# - Variant: fp16 (16-bit floating-point precision)

# %%
pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, use_safetensors=True, variant="fp16")
pipe.to("cuda")

# %% [markdown]
# ## **Defining a prompt for image generation**

# %%
prompt = "An astronaut riding a golden horse to the moon"

images = pipe(prompt=prompt).images[0]

# %% [markdown]
# # **Displaying Generated Image**

# %%
images
